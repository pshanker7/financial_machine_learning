# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def get_mean_volume(symbol):
    #Data for a stock is stored as data/<symbol>.csv
    df = pd.read_csv("data/{}.csv".format(symbol))
    return df['Volume'].mean()

# %%
def get_max_close(symbol):
    #Returns the maximum closing value for the stock 
    df = pd.read_csv("data/{}.csv".format(symbol)) #Read data
    return df['Close'].max()

# %%
def test_run():
    #Plot Apple Data 
    #df = pd.read_csv("data/AAPL.csv")
    #print(df['Adj Close'])
    #df['Adj Close'].plot()
    #plt.show()
    
    #print(df.tail(5)) #Prints the last 5 rows of the dataframe
    
    #Plot IBM Data 
    #df = pd.read_csv("data/IBM.csv")
    #df['High'].plot()
    #plt.show()
    
    #Plot 2 Columns on Apple Data 
    df = pd.read_csv("data/AAPL.csv")
    df[['Close','Adj Close']].plot()
    plt.show()
    '''
    for symbol in ['AAPL','IBM']:
        print("Max close")
        print (symbol,get_max_close(symbol))
        print ("Mean Volume")
        print (symbol,get_mean_volume(symbol))
    '''

# %%
if __name__ == '__main__':
    test_run()
